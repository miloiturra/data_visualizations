# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("../")
from plots import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = pd.read_csv('../data/adult.csv')

# %%
numerical_feats = [
    'age',
    'capital-gain',
    'capital-loss',
    'hours-per-week',    
]

categorical_feats = [
    'workclass',
    'educational-num',
    'education',
    'marital-status',
    'race',
    'relationship',
    'gender',
    'native-country',
    'occupation',
]

target = 'income'

# %%
compare_numerical_features(data, numerical_feats, groupby=target, nbins=20)
# Out:
# <div>
#
#
#             <div id="af3c6a78-38c2-42b9-b2ec-c1c1fbdec30b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("af3c6a78-38c2-42b9-b2ec-c1c1fbdec30b")) {
#                     Plotly.newPlot(
#                         'af3c6a78-38c2-42b9-b2ec-c1c1fbdec30b',
# ...

# %%
compare_categorical_features(data, categorical_feats, groupby=target)
# Out:
# <div>
#
#
#             <div id="75ccce31-e46f-49b2-9fb1-287e154a0a6e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("75ccce31-e46f-49b2-9fb1-287e154a0a6e")) {
#                     Plotly.newPlot(
#                         '75ccce31-e46f-49b2-9fb1-287e154a0a6e',
# ...
